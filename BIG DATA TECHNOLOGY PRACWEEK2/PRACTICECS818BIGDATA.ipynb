# %%
import numpy as np
import pandas as pd

# %%
pokemon= pd.read_csv("pokemon_alopez247.csv")

# %%
pokemon.head(10)
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
# 5       6   Charizard   Fire  Flying    534  78      84       78     109
# 6       7    Squirtle  Water     NaN    314  44      48       65      50
# 7       8   Wartortle  Water     NaN    405  59      63       80      65
# 8       9   Blastoise  Water     NaN    530  79      83      100      85
# 9      10    Caterpie    Bug     NaN    195  45      30       35      20
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# ...

# %%
pokemon.columns
# Out:
# Index(['Number', 'Name', 'Type_1', 'Type_2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'isLegendary',
#        'Color', 'hasGender', 'Pr_Male', 'Egg_Group_1', 'Egg_Group_2',
#        'hasMegaEvolution', 'Height_m', 'Weight_kg', 'Catch_Rate',
#        'Body_Style'],
#       dtype='object')

# %%
pokemon.Attack.sort_values(ascending=False)
# Out:
# 408    165
# 288    160
# 485    160
# 643    150
# 382    150
#       ...
# 128     10
# 212     10
# 241     10
# 112      5
# 439      5
# Name: Attack, Length: 721, dtype: int64

# %%
pokemon.groupby('Type_1').Defense.describe()
# Out:
#           count        mean        std   min    25%    50%     75%    max
# Type_1
# Bug        63.0   67.698413  32.223331  30.0  47.50   55.0   85.00  230.0
# Dark       28.0   67.928571  23.796870  30.0  50.00   67.5   88.50  115.0
# Dragon     24.0   79.125000  22.618408  35.0  63.75   85.0   91.25  121.0
# Electric   36.0   59.083333  20.353132  15.0  40.00   58.5   70.00  115.0
# Fairy      17.0   65.705882  18.979478  28.0  50.00   66.0   75.00   95.0
# Fighting   25.0   64.280000  18.320116  30.0  53.00   62.0   78.00   95.0
# Fire       47.0   64.893617  22.654526  37.0  46.50   60.0   72.00  140.0
# Flying      3.0   61.666667  23.629078  35.0  52.50   70.0   75.00   80.0
# Ghost      23.0   75.956522  33.910951  30.0  51.50   65.0   95.00  145.0
# Grass      66.0   69.363636  23.955495  30.0  50.00   65.0   83.00  131.0
# Ground     30.0   82.166667  31.893231  25.0  51.25   82.0  108.75  140.0
# Ice        23.0   71.043478  35.110835  15.0  47.50   70.0   85.00  184.0
# ...

# %%
pokemon.groupby('Type_2').Defense.describe()
# Out:
#           count        mean        std   min     25%    50%     75%    max
# Type_2
# Bug         3.0   80.000000  26.457513  50.0   70.00   90.0   95.00  100.0
# Dark       16.0   65.750000  27.857973  20.0   43.75   63.5   81.25  110.0
# Dragon     14.0   82.571429  25.095860  35.0   71.75   85.0   98.75  120.0
# Electric    6.0   68.333333  29.486720  38.0   52.00   59.0   78.00  120.0
# Fairy      18.0   64.611111  38.280910  15.0   41.25   58.5   83.75  150.0
# Fighting   19.0   77.947368  23.791861  40.0   65.00   71.0   90.00  129.0
# Fire        9.0   67.222222  24.252720  30.0   55.00   60.0   90.00  100.0
# Flying     87.0   65.413793  23.879324  30.0   47.50   62.0   80.00  140.0
# Ghost      12.0   81.416667  35.464344  45.0   57.50   72.5   85.00  150.0
# Grass      18.0   73.333333  21.898160  30.0   58.75   73.0   83.75  122.0
# Ground     30.0   83.366667  35.571670  40.0   65.75   77.0   93.75  200.0
# ...

# %%
pokemon.groupby(["Type_1"]).Total.agg(["mean", "min", "max","median"])
# Out:
#                 mean  min  max  median
# Type_1
# Bug       365.126984  194  600   390.0
# Dark      434.750000  220  680   438.0
# Dragon    501.958333  300  680   515.0
# Electric  420.694444  205  580   429.5
# Fairy     413.176471  218  680   405.0
# Fighting  404.360000  210  525   455.0
# Fire      443.021277  250  680   460.0
# Flying    453.333333  245  580   535.0
# Ghost     423.652174  275  680   455.0
# Grass     409.560606  180  600   409.0
# Ground    421.000000  265  670   427.5
# Ice       427.086957  250  580   455.0
# Normal    392.161290  190  720   411.0
# Poison    399.142857  245  535   401.5
# Psychic   442.489362  198  680   466.0
# Rock      437.804878  280  600   440.0
# Steel     464.909091  300  680   467.5
# Water     417.200000  200  680   430.0

# %%
p=pokemon.groupby("Type_1").size().reset_index(name='counts')
p=p.sort_values(['counts'],ascending=False)
p.head(1)
# Out:
#    Type_1  counts
# 17  Water     105

# %%
pokemon.isnull().any()
# Out:
# Number              False
# Name                False
# Type_1              False
# Type_2               True
# Total               False
# HP                  False
# Attack              False
# Defense             False
# Sp_Atk              False
# Sp_Def              False
# Speed               False
# Generation          False
# isLegendary         False
# Color               False
# hasGender           False
# Pr_Male              True
# Egg_Group_1         False
# Egg_Group_2          True
# hasMegaEvolution    False
# Height_m            False
# Weight_kg           False
# Catch_Rate          False
# Body_Style          False
# dtype: bool

# %%
pokemon.isnull().sum()
# Out:
# Number                0
# Name                  0
# Type_1                0
# Type_2              371
# Total                 0
# HP                    0
# Attack                0
# Defense               0
# Sp_Atk                0
# Sp_Def                0
# Speed                 0
# Generation            0
# isLegendary           0
# Color                 0
# hasGender             0
# Pr_Male              77
# Egg_Group_1           0
# Egg_Group_2         530
# hasMegaEvolution      0
# Height_m              0
# Weight_kg             0
# Catch_Rate            0
# Body_Style            0
# dtype: int64

# %%
pokemon=pokemon.drop("Type_2", axis=1)
pokemon=pokemon.drop("Egg_Group_2",axis=1)
pokemon
# Out:
#      Number        Name   Type_1  Total   HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0         1   Bulbasaur    Grass    318   45      49       49      65      65
# 1         2     Ivysaur    Grass    405   60      62       63      80      80
# 2         3    Venusaur    Grass    525   80      82       83     100     100
# 3         4  Charmander     Fire    309   39      52       43      60      50
# 4         5  Charmeleon     Fire    405   58      64       58      80      65
# ..      ...         ...      ...    ...  ...     ...      ...     ...     ...
# 716     717     Yveltal     Dark    680  126     131       95     131      98
# 717     718     Zygarde   Dragon    600  108     100      121      81      95
# 718     719     Diancie     Rock    600   50     100      150     100     150
# 719     720       Hoopa  Psychic    600   80     110       60     150     130
# 720     721   Volcanion     Fire    600   80     110      120     130      90
#
# ...

# %%
pokemon= pokemon.dropna()
pokemon
# Out:
#      Number        Name  Type_1  Total  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0         1   Bulbasaur   Grass    318  45      49       49      65      65
# 1         2     Ivysaur   Grass    405  60      62       63      80      80
# 2         3    Venusaur   Grass    525  80      82       83     100     100
# 3         4  Charmander    Fire    309  39      52       43      60      50
# 4         5  Charmeleon    Fire    405  58      64       58      80      65
# ..      ...         ...     ...    ...  ..     ...      ...     ...     ...
# 710     711   Gourgeist   Ghost    494  65      90      122      58      75
# 711     712    Bergmite     Ice    304  55      69       85      32      35
# 712     713     Avalugg     Ice    514  95     117      184      44      46
# 713     714      Noibat  Flying    245  40      30       35      45      40
# 714     715     Noivern  Flying    535  85      70       80      97      80
#
# ...

# %%
# VISUALISATION  WITH SINGLE VARIABLE

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=pd.read_csv("train.csv")

# %%
titanic.plot(kind='box',subplots=True,layout=(3,3))
plt.show()

# %%
titanic['Survived'].value_counts().plot.bar()
plt.title('Titanic survivor vs fartiles')
plt.show()

# %%
titanic['Pclass'].value_counts().sort_values(ascending=False).plot.barh()
plt.title('Passenger classes')
plt.show()

# %%
titanic['SibSp'].plot.density()
plt.show()

# %%
titanic.groupby(['Pclass','Sex']).size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
corr = titanic.corr(numeric_only = True)
sns.heatmap(corr)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(titanic["Age"], titanic["Pclass"], color='g', marker='^')
ax.scatter(titanic["Age"], titanic["SibSp"], color='y', marker = '*')
plt.show()
